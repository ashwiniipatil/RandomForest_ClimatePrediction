# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('temps.csv')

# %%
df
# Out:
#      year  month  day   week  temp_2  temp_1  average  actual  friend
# 0    2019      1    1    Fri      45      45     45.6      45      29
# 1    2019      1    2    Sat      44      45     45.7      44      61
# 2    2019      1    3    Sun      45      44     45.8      41      56
# 3    2019      1    4    Mon      44      41     45.9      40      53
# 4    2019      1    5   Tues      41      40     46.0      44      41
# ..    ...    ...  ...    ...     ...     ...      ...     ...     ...
# 343  2019     12   27   Tues      42      42     45.2      47      47
# 344  2019     12   28    Wed      42      47     45.3      48      58
# 345  2019     12   29  Thurs      47      48     45.3      48      65
# 346  2019     12   30    Fri      48      48     45.4      57      42
# 347  2019     12   31    Sat      48      57     45.5      40      57
#
# [348 rows x 9 columns]

# %%
#shape of features after one hot encoding
df.shape
# Out:
# (348, 9)

# %%
df.head()
# Out:
#    year  month  day  week  temp_2  temp_1  average  actual  friend
# 0  2019      1    1   Fri      45      45     45.6      45      29
# 1  2019      1    2   Sat      44      45     45.7      44      61
# 2  2019      1    3   Sun      45      44     45.8      41      56
# 3  2019      1    4   Mon      44      41     45.9      40      53
# 4  2019      1    5  Tues      41      40     46.0      44      41

# %%
df.tail()
# Out:
#      year  month  day   week  temp_2  temp_1  average  actual  friend
# 343  2019     12   27   Tues      42      42     45.2      47      47
# 344  2019     12   28    Wed      42      47     45.3      48      58
# 345  2019     12   29  Thurs      47      48     45.3      48      65
# 346  2019     12   30    Fri      48      48     45.4      57      42
# 347  2019     12   31    Sat      48      57     45.5      40      57

# %%
#isnull() is use to find out null values from dataset
df.isnull().sum()

# %%
df.columns
# Out:
# Index(['year', 'month', 'day', 'week', 'temp_2', 'temp_1', 'average', 'actual',
#        'friend'],
#       dtype='object')

# %% [markdown]
# One-Hot Encoding

# %% [markdown]
# One hot encoding is a technique that we use to represent categorical variables as numerical values in a machine learning model.

# %% [markdown]
# get_dummies() function creates dummy variables from categorical variables.

# %%
df = pd.get_dummies(df)

# %%
df.head()
# Out:
#    year  month  day  temp_2  temp_1  average  actual  friend  week_Fri  \
# 0  2019      1    1      45      45     45.6      45      29      True
# 1  2019      1    2      44      45     45.7      44      61     False
# 2  2019      1    3      45      44     45.8      41      56     False
# 3  2019      1    4      44      41     45.9      40      53     False
# 4  2019      1    5      41      40     46.0      44      41     False
#
#    week_Mon  week_Sat  week_Sun  week_Thurs  week_Tues  week_Wed
# 0     False     False     False       False      False     False
# 1     False      True     False       False      False     False
# 2     False     False      True       False      False     False
# 3      True     False     False       False      False     False
# 4     False     False     False       False       True     False

# %%
#dependent features
y = df.iloc[:,7]

# %%
y
# Out:
# 0      29
# 1      61
# 2      56
# 3      53
# 4      41
#        ..
# 343    47
# 344    58
# 345    65
# 346    42
# 347    57
# Name: friend, Length: 348, dtype: int64

# %%
#independent features
x = df.iloc[:,[1,2,3,4,5,7,8,9,10,11,12,13,14]]

# %%
x
# Out:
#      month  day  temp_2  temp_1  average  friend  week_Fri  week_Mon  \
# 0        1    1      45      45     45.6      29      True     False
# 1        1    2      44      45     45.7      61     False     False
# 2        1    3      45      44     45.8      56     False     False
# 3        1    4      44      41     45.9      53     False      True
# 4        1    5      41      40     46.0      41     False     False
# ..     ...  ...     ...     ...      ...     ...       ...       ...
# 343     12   27      42      42     45.2      47     False     False
# 344     12   28      42      47     45.3      58     False     False
# 345     12   29      47      48     45.3      65     False     False
# 346     12   30      48      48     45.4      42      True     False
# 347     12   31      48      57     45.5      57     False     False
#
#      week_Sat  week_Sun  week_Thurs  week_Tues  week_Wed
# 0       False     False       False      False     False
# ...

# %% [markdown]
# Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size = 0.25,random_state=100)

# %%
print("Training feature Shape:",X_train.shape)
print("Training feature Labels",X_test.shape)
print("Training feature Shape:",y_train.shape)
print("Training feature Labels",y_test.shape)
# Out:
# Training feature Shape: (87, 14)
# Training feature Labels (261, 14)
# Training feature Shape: (87,)
# Training feature Labels (261,)

# %% [markdown]
# Training the forest

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
reg = RandomForestRegressor(n_estimators = 999, random_state=45)

# %%
reg.fit (X_train,y_train)
# Out:
# RandomForestRegressor(n_estimators=999, random_state=45)

# %%
y_pred = reg.predict(X_test)

# %%
y_pred
# Out:
# array([77.76776777, 72.73573574, 32.73373373, 34.85685686, 46.4024024 ,
#        58.13013013, 69.85185185, 58.28128128, 65.64764765, 84.74474474,
#        60.92092092, 62.02102102, 86.64364364, 77.67767768, 34.68768769,
#        53.68368368, 71.5035035 , 66.7017017 , 40.73173173, 77.30530531,
#        53.79079079, 61.87187187, 51.61961962, 45.72172172, 59.77777778,
#        64.25825826, 66.61261261, 89.06306306, 56.75975976, 88.72872873,
#        87.94994995, 86.17017017, 38.07407407, 38.84984985, 61.10710711,
#        65.65665666, 56.28128128, 74.12412412, 34.45245245, 51.45945946,
#        59.74274274, 70.14914915, 58.27027027, 38.80880881, 62.48548549,
#        38.75675676, 55.93493493, 37.15615616, 74.02202202, 61.98198198,
#        70.21821822, 74.15915916, 51.26626627, 44.92692693, 70.13213213,
#        65.56856857, 59.74874875, 57.8998999 , 64.89089089, 56.76476476,
#        77.7017017 , 41.28228228, 77.24624625, 37.97597598, 55.95395395,
# ...

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 1.7936284748154085

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 0.7730028879454167
